# %%
import torch
from torchvision import datasets, transforms

import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
from torchvision import datasets
import torchvision.transforms as transforms

#number of subprocesses to use for data loading
num_workers = 0
#how many samples per batch to load
batch_size = 20

# %%
# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# choose the training and test datasets
train_data = datasets.CIFAR10('data', train=True,
                              download=True, transform=transform)

valid_data = datasets.CIFAR10('data', train=False,
                             download=True, transform=transform)

# prepare data loaders

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers)

valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size, num_workers=num_workers)

# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images[labels<5]
print(len(images))
labels = labels[labels<5]
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(len(images)):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])
# Out:
# 9

# %%
import torch.nn as nn
import torch.nn.functional as F

#Define CNN structure
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        #Convolutional layer (32x32x3 image tensor)
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        #convolutional layer (16x16x16)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        #convolutional layer (8x8x32)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1)
        # max pooling layer
        self.pool = nn.MaxPool2d(2, 2)
        # linear layer (64 * 4 * 4 -> 500)
        self.fc1 = nn.Linear(64*4*4, 512)
        # linear layer (500 -> 10)
        self.fc2 = nn.Linear(512,5)
        #dropout layer (p=0.2)
        self.dropout = nn.Dropout(0.3)
        
    def forward(self,x):
        #Adding sequence of convolution and max pooling layers
        
        # (32x32x3 image tensor)
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool(x)
        # (16x16x16 image tensor)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)
        # (8x8x32 image tensor)
        x = self.conv3(x)
        x = F.relu(x)
        x = self.pool(x)
        # (4x4x64 image tensor)
        # flatten image input
        x = x.view(-1, 64 * 4 * 4)
    
        x = self.dropout(x)
        #First hidden layer with relu activation function
        x = F.relu(self.fc1(x))    
        #add 1st dropout layer
        x = self.dropout(x)
        #add 2nd hidden layer
        x = self.fc2(x)
        
        return x
    
#Complete CNN
model = Net()
print(model)

#move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=5, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %%
pytorch_total_params = sum(p.numel() for p in model.parameters())
pytorch_total_params
# Out:
# 550949

# %%
# Define loss and optimizer 
import torch.optim as optim

#specify loss function
criterion = nn.CrossEntropyLoss()

#specify optimizer
optimizer = optim.SGD(model.parameters(),lr=0.001)

# %%
#number of epochs to train the model
n_epochs = 70

train_loss_store = []
valid_loss_store = []

for epoch in range(1,n_epochs+1):
    
    #keep track of training and validation
    train_loss = 0.0
    valid_loss = 0.0
    train_correct = 0
    valid_correct = 0
    valid_img = 0
    train_img = 0
    
    #Training of Model
    model.train()
    for data, target in train_loader:
        #move tensor to GPU if CUDA is available
        data = data[target<5]
        target = target[target<5]
        
        #print(len(data))
        #print(len(target))
        
        train_img += len(data)
        
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
            
        #clear the gradient of all optimized variables
        optimizer.zero_grad()
        #forward pass compute predicted output
        output = model(data)
        #calculate the batch loss
        loss = criterion(output, target)
    
        #checking correct classes
        top_p, top_class = output.topk(1, dim=1)
        #find number of correct classes predicted
        top_p, top_class = output.topk(1, dim=1)
        #print(top_class)
        for i in range(len(data)):
            if target[i] == top_class[i]:
                train_correct += 1         
                
        #backward pass compute the gradient of loss with respect to model parameter
        loss.backward()
        #perform optimizer step
        optimizer.step()
        #update training loss
        train_loss += loss.item()*data.size(0)
        
    #Validate the model
    model.eval()
    for data, target in valid_loader:
        #move tensor to GPU if CUDA is available
#         print(target.shape)
        data = data[target<5]
        target = target[target<5]
        
        valid_img += len(data)
        
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
            
        #forward pass compute output by passing through optimized model
        output = model(data)
        #print(output.shape)
        #batch loss calculation
        loss = criterion(output,target)
        
        #checking correct classes
        top_p, top_class = output.topk(1, dim=1)
        #find number of correct classes predicted
        top_p, top_class = output.topk(1, dim=1)
        #print(top_class)
        for i in range(len(data)):
            if target[i] == top_class[i]:
                valid_correct += 1 
                
        #update validation loss
        valid_loss += loss.item()*data.size(0)
        
    #calculation of average losses
    train_loss = train_loss/(train_img)
    valid_loss = valid_loss/(valid_img)
    valid_accuracy = valid_correct/(valid_img)
    train_accuracy = train_correct/(train_img)
    
    train_loss_store.append(train_loss)
    valid_loss_store.append(valid_loss)
    
    
    #if epoch == 40:
    #   torch.save(model.state_dict(), 'model_cifar.pt')
        
    
    print("Epoch:{} \t Train_loss: {:.6f} \t Valid_loss: {:.6f} \t Train accuracy: {:.6f} \t Valid accuracy {:.6f}".format(epoch, train_loss,valid_loss, train_accuracy, valid_accuracy))
        
    #plt.plot(train_loss_store, label='Training loss')
    #plt.plot(valid_loss_store, label='Validation loss')
    #plt.legend(frameon=False)
    #plt.savefig('final.png', dpi=100)
    #plt.show()
# Out:
# Epoch:1 	 Train_loss: 1.605358 	 Valid_loss: 1.596481 	 Train accuracy: 0.220280 	 Valid accuracy 0.208400
# Epoch:2 	 Train_loss: 1.578427 	 Valid_loss: 1.539628 	 Train accuracy: 0.253800 	 Valid accuracy 0.319000
# Epoch:3 	 Train_loss: 1.510744 	 Valid_loss: 1.452085 	 Train accuracy: 0.363360 	 Valid accuracy 0.410200
# Epoch:4 	 Train_loss: 1.437782 	 Valid_loss: 1.379953 	 Train accuracy: 0.408080 	 Valid accuracy 0.438000
# Epoch:5 	 Train_loss: 1.385772 	 Valid_loss: 1.327858 	 Train accuracy: 0.426880 	 Valid accuracy 0.460200
# Epoch:6 	 Train_loss: 1.330289 	 Valid_loss: 1.254033 	 Train accuracy: 0.448600 	 Valid accuracy 0.491200
# Epoch:7 	 Train_loss: 1.235021 	 Valid_loss: 1.138039 	 Train accuracy: 0.494960 	 Valid accuracy 0.538600
# Epoch:8 	 Train_loss: 1.138200 	 Valid_loss: 1.072320 	 Train accuracy: 0.531640 	 Valid accuracy 0.550200
# Epoch:9 	 Train_loss: 1.083872 	 Valid_loss: 1.034070 	 Train accuracy: 0.552080 	 Valid accuracy 0.571000
# Epoch:10 	 Train_loss: 1.050692 	 Valid_loss: 1.000187 	 Train accuracy: 0.567280 	 Valid accuracy 0.585000
# Epoch:11 	 Train_loss: 1.026542 	 Valid_loss: 0.982146 	 Train accuracy: 0.578200 	 Valid accuracy 0.590400
# Epoch:12 	 Train_loss: 1.005306 	 Valid_loss: 0.962742 	 Train accuracy: 0.587800 	 Valid accuracy 0.598800
# Epoch:13 	 Train_loss: 0.984775 	 Valid_loss: 0.947300 	 Train accuracy: 0.600000 	 Valid accuracy 0.609200
# Epoch:14 	 Train_loss: 0.968559 	 Valid_loss: 0.922717 	 Train accuracy: 0.607320 	 Valid accuracy 0.621800
# Epoch:15 	 Train_loss: 0.953642 	 Valid_loss: 0.908555 	 Train accuracy: 0.616320 	 Valid accuracy 0.628000
# Epoch:16 	 Train_loss: 0.938155 	 Valid_loss: 0.901962 	 Train accuracy: 0.618200 	 Valid accuracy 0.630600
# Epoch:17 	 Train_loss: 0.922416 	 Valid_loss: 0.886490 	 Train accuracy: 0.628800 	 Valid accuracy 0.638000
# Epoch:18 	 Train_loss: 0.910927 	 Valid_loss: 0.876222 	 Train accuracy: 0.634000 	 Valid accuracy 0.638800
# Epoch:19 	 Train_loss: 0.897476 	 Valid_loss: 0.864106 	 Train accuracy: 0.639040 	 Valid accuracy 0.645200
# Epoch:20 	 Train_loss: 0.888639 	 Valid_loss: 0.851233 	 Train accuracy: 0.642640 	 Valid accuracy 0.652000
# Epoch:21 	 Train_loss: 0.877439 	 Valid_loss: 0.841209 	 Train accuracy: 0.650400 	 Valid accuracy 0.658000
# Epoch:22 	 Train_loss: 0.866500 	 Valid_loss: 0.832258 	 Train accuracy: 0.652720 	 Valid accuracy 0.665000
# Epoch:23 	 Train_loss: 0.855390 	 Valid_loss: 0.823991 	 Train accuracy: 0.657880 	 Valid accuracy 0.670600
# Epoch:48 	 Train_loss: 0.645963 	 Valid_loss: 0.636198 	 Train accuracy: 0.752240 	 Valid accuracy 0.750600
# Epoch:49 	 Train_loss: 0.643546 	 Valid_loss: 0.631105 	 Train accuracy: 0.754520 	 Valid accuracy 0.755800
# Epoch:50 	 Train_loss: 0.636134 	 Valid_loss: 0.627502 	 Train accuracy: 0.759000 	 Valid accuracy 0.757600
# Epoch:51 	 Train_loss: 0.624053 	 Valid_loss: 0.623461 	 Train accuracy: 0.762200 	 Valid accuracy 0.759800
# Epoch:52 	 Train_loss: 0.623913 	 Valid_loss: 0.620812 	 Train accuracy: 0.761680 	 Valid accuracy 0.762600
# Epoch:53 	 Train_loss: 0.616853 	 Valid_loss: 0.616361 	 Train accuracy: 0.767160 	 Valid accuracy 0.763400
# Epoch:54 	 Train_loss: 0.610583 	 Valid_loss: 0.611731 	 Train accuracy: 0.768160 	 Valid accuracy 0.765200
# Epoch:55 	 Train_loss: 0.603402 	 Valid_loss: 0.612161 	 Train accuracy: 0.771560 	 Valid accuracy 0.764800
# Epoch:56 	 Train_loss: 0.598227 	 Valid_loss: 0.606681 	 Train accuracy: 0.773440 	 Valid accuracy 0.768200
# Epoch:57 	 Train_loss: 0.594827 	 Valid_loss: 0.597478 	 Train accuracy: 0.775800 	 Valid accuracy 0.772200
# Epoch:58 	 Train_loss: 0.588717 	 Valid_loss: 0.600891 	 Train accuracy: 0.776600 	 Valid accuracy 0.771200
# Epoch:59 	 Train_loss: 0.583163 	 Valid_loss: 0.588417 	 Train accuracy: 0.780800 	 Valid accuracy 0.772400
# Epoch:60 	 Train_loss: 0.578250 	 Valid_loss: 0.588084 	 Train accuracy: 0.779720 	 Valid accuracy 0.774600
# Epoch:61 	 Train_loss: 0.574246 	 Valid_loss: 0.586542 	 Train accuracy: 0.786760 	 Valid accuracy 0.776800
# Epoch:62 	 Train_loss: 0.571296 	 Valid_loss: 0.585534 	 Train accuracy: 0.783400 	 Valid accuracy 0.777400
# Epoch:63 	 Train_loss: 0.561958 	 Valid_loss: 0.581942 	 Train accuracy: 0.789960 	 Valid accuracy 0.780200
# Epoch:64 	 Train_loss: 0.562807 	 Valid_loss: 0.579964 	 Train accuracy: 0.788840 	 Valid accuracy 0.778800
# Epoch:65 	 Train_loss: 0.555798 	 Valid_loss: 0.575380 	 Train accuracy: 0.792960 	 Valid accuracy 0.779800
# Epoch:66 	 Train_loss: 0.551132 	 Valid_loss: 0.568274 	 Train accuracy: 0.792040 	 Valid accuracy 0.785200
# Epoch:67 	 Train_loss: 0.547565 	 Valid_loss: 0.564090 	 Train accuracy: 0.794040 	 Valid accuracy 0.784200
# Epoch:68 	 Train_loss: 0.540657 	 Valid_loss: 0.567588 	 Train accuracy: 0.798880 	 Valid accuracy 0.782800
# Epoch:69 	 Train_loss: 0.537739 	 Valid_loss: 0.566965 	 Train accuracy: 0.797440 	 Valid accuracy 0.785800
# Epoch:70 	 Train_loss: 0.533257 	 Valid_loss: 0.562184 	 Train accuracy: 0.800440 	 Valid accuracy 0.787000

# %%
plt.plot(train_loss_store, label='Training loss')
plt.plot(valid_loss_store, label='Validation loss')
plt.legend(frameon=False)
#plt.savefig('cnn_5', dpi=100)
plt.show()
